# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/python/3.10.13/lib/python3.10/site-packages (2.0.30)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/codespace/.local/lib/python3.10/site-packages (from sqlalchemy) (4.12.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from sqlalchemy) (3.0.3)

# %%
# !pip install pyodbc
# Out:
# Collecting pyodbc
#   Downloading pyodbc-5.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Downloading pyodbc-5.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (334 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.7/334.7 kB 7.1 MB/s eta 0:00:00:00:01
# Installing collected packages: pyodbc
# Successfully installed pyodbc-5.1.0

# %%
# !pip install "pymongo[srv]"
# Out:
# Collecting pymongo[srv]
#   Downloading pymongo-4.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo[srv])
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 5.4 MB/s eta 0:00:00:00:01
# Downloading pymongo-4.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (669 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 669.1/669.1 kB 18.3 MB/s eta 0:00:0000:01
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.7.3

# %%
# !pip install mysqlclient
# Out:
# Collecting mysqlclient
#   Downloading mysqlclient-2.2.4.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 2.3 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: mysqlclient
#   Building wheel for mysqlclient (pyproject.toml) ... done
#   Created wheel for mysqlclient: filename=mysqlclient-2.2.4-cp310-cp310-linux_x86_64.whl size=132260 sha256=302844ee254b720aa835cb9f1fbd71a18ac1af058efddd5a5e74f7b65874c4d1
#   Stored in directory: /home/codespace/.cache/pip/wheels/ac/96/ac/2a4d8cb58a4d95de1dffc3f8b0ea42e0e5b63ab97640edbda3
# Successfully built mysqlclient
# Installing collected packages: mysqlclient
# Successfully installed mysqlclient-2.2.4

# %%
import sqlalchemy as db
from sqlalchemy import text
import pandas as pd
from pymongo import MongoClient

# %%
engine = db.create_engine("mysql://root:root@172.16.5.4:3310/retail_db")
conn = engine.connect()

# %%
df_customers = pd.read_sql_query('SELECT * FROM customers', con=conn)
df_customers.tail()
# Out:
#        customer_id customer_fname customer_lname customer_email  \
# 12430        12431           Mary           Rios      XXXXXXXXX
# 12431        12432         Angela          Smith      XXXXXXXXX
# 12432        12433       Benjamin         Garcia      XXXXXXXXX
# 12433        12434           Mary          Mills      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
#
#       customer_password             customer_street customer_city  \
# 12430         XXXXXXXXX           1221 Cinder Pines       Kaneohe
# 12431         XXXXXXXXX  1525 Jagged Barn Highlands        Caguas
# 12432         XXXXXXXXX    5459 Noble Brook Landing     Levittown
# 12433         XXXXXXXXX        9720 Colonial Parade        Caguas
# 12434         XXXXXXXXX            5736 Honey Downs   Summerville
#
#       customer_state customer_zipcode
# 12430             HI            96744
# 12431             PR            00725
# 12432             NY            11756
# 12433             PR            00725
# 12434             SC            29483

# %%
# conexion a mongo db
CONNECTION_STRING = "mongodb+srv://m001-student:HIpdw3iyNh74KjTw@sandbox.okkbl.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(CONNECTION_STRING)

# %%
dbname = client["retail_db"]

# %%
df = df_customers.copy()
df_to_dict = df.to_dict("records")
dbname["customers"].insert_many(df_to_dict)
# Out:
# InsertManyResult([ObjectId('666b9ec17443dafabfa63e4c'), ObjectId('666b9ec17443dafabfa63e4d'), ObjectId('666b9ec17443dafabfa63e4e'), ObjectId('666b9ec17443dafabfa63e4f'), ObjectId('666b9ec17443dafabfa63e50'), ObjectId('666b9ec17443dafabfa63e51'), ObjectId('666b9ec17443dafabfa63e52'), ObjectId('666b9ec17443dafabfa63e53'), ObjectId('666b9ec17443dafabfa63e54'), ObjectId('666b9ec17443dafabfa63e55'), ObjectId('666b9ec17443dafabfa63e56'), ObjectId('666b9ec17443dafabfa63e57'), ObjectId('666b9ec17443dafabfa63e58'), ObjectId('666b9ec17443dafabfa63e59'), ObjectId('666b9ec17443dafabfa63e5a'), ObjectId('666b9ec17443dafabfa63e5b'), ObjectId('666b9ec17443dafabfa63e5c'), ObjectId('666b9ec17443dafabfa63e5d'), ObjectId('666b9ec17443dafabfa63e5e'), ObjectId('666b9ec17443dafabfa63e5f'), ObjectId('666b9ec17443dafabfa63e60'), ObjectId('666b9ec17443dafabfa63e61'), ObjectId('666b9ec17443dafabfa63e62'), ObjectId('666b9ec17443dafabfa63e63'), ObjectId('666b9ec17443dafabfa63e64'), ObjectId('666b9ec17443dafabfa63e65'), ObjectId('666b9ec17443dafabfa63e66'), ObjectId('666b9ec17443dafabfa63e67'), ObjectId('666b9ec17443dafabfa63e68'), ObjectId('666b9ec17443dafabfa63e69'), ObjectId('666b9ec17443dafabfa63e6a'), ObjectId('666b9ec17443dafabfa63e6b'), ObjectId('666b9ec17443dafabfa63e6c'), ObjectId('666b9ec17443dafabfa63e6d'), ObjectId('666b9ec17443dafabfa63e6e'), ObjectId('666b9ec17443dafabfa63e6f'), ObjectId('666b9ec17443dafabfa63e70'), ObjectId('666b9ec17443dafabfa63e71'), ObjectId('666b9ec17443dafabfa63e72'), ObjectId('666b9ec17443dafabfa63e73'), ObjectId('666b9ec17443dafabfa63e74'), ObjectId('666b9ec17443dafabfa63e75'), ObjectId('666b9ec17443dafabfa63e76'), ObjectId('666b9ec17443dafabfa63e77'), ObjectId('666b9ec17443dafabfa63e78'), ObjectId('666b9ec17443dafabfa63e79'), ObjectId('666b9ec17443dafabfa63e7a'), ObjectId('666b9ec17443dafabfa63e7b'), ObjectId('666b9ec17443dafabfa63e7c'), ObjectId('666b9ec17443dafabfa63e7d'), ObjectId('666b9ec17443dafabfa63e7e'), ObjectId('666b9ec17443dafabfa63e7f'), ObjectId('666b9ec17443dafabfa63e80'), ObjectId('666b9ec17443dafabfa63e81'), ObjectId('666b9ec17443dafabfa63e82'), ObjectId('666b9ec17443dafabfa63e83'), ObjectId('666b9ec17443dafabfa63e84'), ObjectId('666b9ec17443dafabfa63e85'), ObjectId('666b9ec17443dafabfa63e86'), ObjectId('666b9ec17443dafabfa63e87'), ObjectId('666b9ec17443dafabfa63e88'), ObjectId('666b9ec17443dafabfa63e89'), ObjectId('666b9ec17443dafabfa63e8a'), ObjectId('666b9ec17443dafabfa63e8b'), ObjectId('666b9ec17443dafabfa63e8c'), ObjectId('666b9ec17443dafabfa63e8d'), ObjectId('666b9ec17443dafabfa63e8e'), ObjectId('666b9ec17443dafabfa63e8f'), ObjectId('666b9ec17443dafabfa63e90'), ObjectId('666b9ec17443dafabfa63e91'), ObjectId('666b9ec17443dafabfa63e92'), ObjectId('666b9ec17443dafabfa63e93'), ObjectId('666b9ec17443dafabfa63e94'), ObjectId('666b9ec17443dafabfa63e95'), ObjectId('666b9ec17443dafabfa63e96'), ObjectId('666b9ec17443dafabfa63e97'), ObjectId('666b9ec17443dafabfa63e98'), ObjectId('666b9ec17443dafabfa63e99'), ObjectId('666b9ec17443dafabfa63e9a'), ObjectId('666b9ec17443dafabfa63e9b'), ObjectId('666b9ec17443dafabfa63e9c'), ObjectId('666b9ec17443dafabfa63e9d'), ObjectId('666b9ec17443dafabfa63e9e'), ObjectId('666b9ec17443dafabfa63e9f'), ObjectId('666b9ec17443dafabfa63ea0'), ObjectId('666b9ec17443dafabfa63ea1'), ObjectId('666b9ec17443dafabfa63ea2'), ObjectId('666b9ec17443dafabfa63ea3'), ObjectId('666b9ec17443dafabfa63ea4'), ObjectId('666b9ec17443dafabfa63ea5'), ObjectId('666b9ec17443dafabfa63ea6'), ObjectId('666b9ec17443dafabfa63ea7'), ObjectId('666b9ec17443dafabfa63ea8'), ObjectId('666b9ec17443dafabfa63ea9'), ObjectId('666b9ec17443dafabfa63eaa'), ObjectId('666b9ec17443dafabfa63eab'), ObjectId('666b9ec17443dafabfa63eac'), ObjectId('666b9ec17443dafabfa63ead'), ObjectId('666b9ec17443dafabfa63eae'), ObjectId('666b9ec17443dafabfa63eaf'), ObjectId('666b9ec17443dafabfa63eb0'), ObjectId('666b9ec17443dafabfa63eb1'), ObjectId('666b9ec17443dafabfa63eb2'), ObjectId('666b9ec17443dafabfa63eb3'), ObjectId('666b9ec17443dafabfa6 ...

# %%
collection_customers = dbname["customers"]

customers = collection_customers.find({})

customers

# %%
df_customers_mongo = pd.DataFrame(customers)
df_customers_mongo
# Out:
# Empty DataFrame
# Columns: []
# Index: []
